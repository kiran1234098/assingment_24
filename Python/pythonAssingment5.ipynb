# %% [markdown]
# Question 5 -
# Write a program to download the data from the given API link and then extract the following data with
# proper formatting
#
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes
# Note - Write proper code comments wherever needed for the code understanding
# Excepted Output Data Attributes -
# ● id - int url - string
# ● name - string season
# ● - int number - int
# ● type - string airdate -
# ● date format airtime -
# ● 12-hour time format
# ● runtime - float
# ● average rating - float
# ● summary - string
# ● without html tags
# ● medium image link - string
# ● Original image link - string

# %%
import requests
import pandas as pd
import re

# API endpoint
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
episodes = data["_embedded"]["episodes"]

# %%
print(data["_embedded"])
# Out:
# {'episodes': [{'id': 869671, 'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original', 'name': 'The Original', 'season': 1, 'number': 1, 'type': 'regular', 'airdate': '2016-10-02', 'airtime': '21:00', 'airstamp': '2016-10-03T01:00:00+00:00', 'runtime': 68, 'rating': {'average': 8}, 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'}, 'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>", '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'}, 'show': {'href': 'https://api.tvmaze.com/shows/1371'}}}, {'id': 911201, 'url': 'https://www.tvmaze
# ...

# %%
episodes
# Out:
# [{'id': 869671,
#   'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#   'name': 'The Original',
#   'season': 1,
#   'number': 1,
#   'type': 'regular',
#   'airdate': '2016-10-02',
#   'airtime': '21:00',
#   'airstamp': '2016-10-03T01:00:00+00:00',
#   'runtime': 68,
#   'rating': {'average': 8},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
#   'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>",
#   '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'},
# ...

# %%
episode_df = pd.DataFrame(episodes)

# %%
episode_df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
# 1       1       2  regular  2016-10-09   21:00  2016-10-10T01:00:00+00:00
#
#    runtime            rating  \
# 0       68    {'average': 8}
# 1       60  {'average': 7.7}
#
#                                                image  \
# 0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
# 1  <p>Bernard suspects that someone is sabotaging...
#
#                                               _links
# ...

# %%
df=episode_df

# %%
episode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        36 non-null     int64
#  1   url       36 non-null     object
#  2   name      36 non-null     object
#  3   season    36 non-null     int64
#  4   number    36 non-null     int64
#  5   type      36 non-null     object
#  6   airdate   36 non-null     object
#  7   airtime   36 non-null     object
#  8   airstamp  36 non-null     object
#  9   runtime   36 non-null     int64
#  10  rating    36 non-null     object
#  11  image     36 non-null     object
#  12  summary   36 non-null     object
#  13  _links    36 non-null     object
# dtypes: int64(4), object(10)
# memory usage: 4.1+ KB

# %%
for i in df['rating']:
    value = next(iter(i.values()))

# Convert the value to a float
    float_value = float(value)
    
    df['average rating']=float_value

# %%
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
#
#    runtime          rating                                              image  \
# 0       68  {'average': 8}  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
#
#                                               _links  average rating
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...             7.5

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
for i in df['summary']:
    

# # Create a BeautifulSoup object from the HTML string
    soup = BeautifulSoup(i, 'html.parser')

# # Get the text without HTML tags
    text_without_tags = soup.get_text()
    df['summary']=text_without_tags

    #print(text_without_tags)

# %%
df['summary']
# Out:
# 0     Like what I've done with the place? (I just cr...
# 1     Like what I've done with the place? (I just cr...
# 2     Like what I've done with the place? (I just cr...
# 3     Like what I've done with the place? (I just cr...
# 4     Like what I've done with the place? (I just cr...
# 5     Like what I've done with the place? (I just cr...
# 6     Like what I've done with the place? (I just cr...
# 7     Like what I've done with the place? (I just cr...
# 8     Like what I've done with the place? (I just cr...
# 9     Like what I've done with the place? (I just cr...
# 10    Like what I've done with the place? (I just cr...
# 11    Like what I've done with the place? (I just cr...
# 12    Like what I've done with the place? (I just cr...
# 13    Like what I've done with the place? (I just cr...
# 14    Like what I've done with the place? (I just cr...
# 15    Like what I've done with the place? (I just cr...
# 16    Like what I've done with the place? (I just cr...
# ...

# %%
for i in df['image']:
        df['medium image link']=i['medium']

# %%
len(df['medium image link'])
# Out:
# 36

# %%
for i in df['image']:
    df['original image link']=i['original']

# %%
for i in df['image']:
    print(i['original'])
# Out:
# https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/78/195436.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/79/198183.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/80/201367.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/81/204265.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/82/207324.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/83/209400.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/84/211554.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/85/213932.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/86/216453.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/152/381118.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/153/382957.jpg
# https://static.tvmaze.com/uploads/images/original_untouched/154/386069.jpg
# ...

# %%
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
#
#    runtime          rating                                              image  \
# 0       68  {'average': 8}  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  Like what I've done with the place? (I just cr...
#
#                                               _links  average rating  \
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...             7.5
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link
# 0  https://static.tvmaze.com/uploads/images/origi...

# %%
df['airstamp'].head()
# Out:
# 0    2016-10-03T01:00:00+00:00
# 1    2016-10-10T01:00:00+00:00
# 2    2016-10-17T01:00:00+00:00
# 3    2016-10-24T01:00:00+00:00
# 4    2016-10-31T01:00:00+00:00
# Name: airstamp, dtype: object

# %%
df['_links'].head(1)
# Out:
# 0    {'self': {'href': 'https://api.tvmaze.com/epis...
# Name: _links, dtype: object

# %%
df.dtypes
# Out:
# id                       int64
# url                     object
# name                    object
# season                   int64
# number                   int64
# type                    object
# airdate                 object
# airtime                 object
# airstamp                object
# runtime                  int64
# rating                  object
# image                   object
# summary                 object
# _links                  object
# average rating         float64
# medium image link       object
# original image link     object
# dtype: object

# %%
df['name']=df['name'].astype('string')
df['type']=df['type'].astype('string')
df['summary']=df['summary'].astype('string')
df['medium image link']=df['medium image link'].astype('string')
df['Original image link']=df['original image link'].astype('string')
df['url']=df['url'].astype('string')

# %%
'''#Excepted Output Data Attributes -
● id - int url - string
● name - string season
● - int number - int
● type - string airdate -
● date format airtime -
● 12-hour time format
● runtime - float
● average rating - float
● summary - string
● without html tags
● medium image link - string
● Original image link - string'''
# Out:
# '#Excepted Output Data Attributes -\n● id - int url - string\n● name - string season\n● - int number - int\n● type - string airdate -\n● date format airtime -\n● 12-hour time format\n● runtime - float\n● average rating - float\n● summary - string\n● without html tags\n● medium image link - string\n● Original image link - string'

# %%
'''
import pandas as pd

# Assuming 'airstamp' column is in string format
df['airstamp'] = pd.to_datetime(df['airstamp'])
df['airtime'] = df['airstamp'].dt.strftime('%Y-%m-%d %I:%M %p')'''

# %%
df['airtime']= df['airstamp'].dt.strftime('%Y-%m-%d %I:%M %p')

# %%
df['airtime']=pd.to_datetime(df['airtime'])

# %%
df['airtime'].head()
# Out:
# 0   2016-10-03 01:00:00
# 1   2016-10-10 01:00:00
# 2   2016-10-17 01:00:00
# 3   2016-10-24 01:00:00
# 4   2016-10-31 01:00:00
# Name: airtime, dtype: datetime64[ns]

# %%
df['runtime']=df['runtime'].astype(float)

# %%
df.dtypes
# Out:
# id                                   int64
# url                         string[python]
# name                        string[python]
# season                               int64
# number                               int64
# type                        string[python]
# airdate                             object
# airtime                     datetime64[ns]
# airstamp               datetime64[ns, UTC]
# runtime                            float64
# rating                              object
# image                               object
# summary                     string[python]
# _links                              object
# average rating                     float64
# medium image link           string[python]
# original image link                 object
# Original image link         string[python]
# dtype: object

# %%
column=['_links','rating','airstamp','airdate']
df.drop(column,axis=1,inplace=True)

# %%
column=['image']
df.drop(column,axis=1,inplace=True)

# %%
df.head(2)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...      Chestnut
#
#    season  number     type             airtime  runtime  \
# 0       1       1  regular 2016-10-03 01:00:00     68.0
# 1       1       2  regular 2016-10-10 01:00:00     60.0
#
#                                              summary  average rating  \
# 0  Like what I've done with the place? (I just cr...             7.5
# 1  Like what I've done with the place? (I just cr...             7.5
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
# 1  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  original image link  \
# 0  https://static.tvmaze.com/uploads/images/origi...
# 1  https://static.tvmaze.com/uploads/images/origi...
#
# ...
